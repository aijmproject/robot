# %%
import pandas as pd 
import numpy as np

# %%
train = pd.read_csv("train.csv")
train["label"].unique()
# Out:
# array(['clay pottery making', 'news anchoring', 'using bagging machine',
#        'javelin throw', 'climbing a rope', 'sipping cup',
#        'flipping pancake', 'tickling', 'watering plants',
#        'eating spaghetti', 'dribbling basketball', 'calligraphy',
#        'playing tennis', 'chiseling stone', 'crossing eyes',
#        'mountain climber (exercise)', 'tap dancing', 'planing wood',
#        'using inhaler', 'playing saxophone', 'slapping', 'shaking head',
#        'lunge', 'driving tractor', 'delivering mail', 'riding a bike',
#        'playing didgeridoo', 'putting in contact lenses', 'shaving head',
#        'doing jigsaw puzzle', 'playing bass guitar',
#        'playing with trains', 'digging', 'brushing teeth', 'washing hair',
#        'opening bottle (not wine)', 'finger snapping', 'doing nails',
#        'making balloon shapes', 'pouring beer', 'preparing salad',
#        'playing violin', 'feeding birds', 'wading through water',
# ...
